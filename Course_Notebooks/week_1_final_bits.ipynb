# %%
# this code conceals irrelevant warning messages
import warnings
warnings.simplefilter('ignore', FutureWarning)

# %%
import pandas as pd

# %%
df = pd.read_csv('../Datasets/Datasets_From_Course/WHO POP TB all.csv')
df
# Out:
#                                                Country  Population (1000s)  \
# 0                                          Afghanistan               30552
# 1                                              Albania                3173
# 2                                              Algeria               39208
# 3                                              Andorra                  79
# 4                                               Angola               21472
# 5                                  Antigua and Barbuda                  90
# 6                                            Argentina               41446
# 7                                              Armenia                2977
# 8                                            Australia               23343
# 9                                              Austria                8495
# 10                                          Azerbaijan                9413
# ...

# %%
df.sort('Population (1000s)', ascending=False)
# Out:
#                                                Country  Population (1000s)  \
# 36                                               China             1393337
# 77                                               India             1252140
# 185                           United States of America              320051
# 78                                           Indonesia              249866
# 23                                              Brazil              200362
# 128                                           Pakistan              182143
# 124                                            Nigeria              173615
# 13                                          Bangladesh              156595
# 141                                 Russian Federation              142834
# 85                                               Japan              127144
# 109                                             Mexico              122332
# ...

# %%
df.sort('TB deaths', ascending=False)
# Out:
#                                    Country  Population (1000s)  TB deaths
# 77                                   India             1252140  240000.00
# 124                                Nigeria              173615  160000.00
# 13                              Bangladesh              156595   80000.00
# 78                               Indonesia              249866   64000.00
# 128                               Pakistan              182143   49000.00
# 47        Democratic Republic of the Congo               67514   46000.00
# 36                                   China             1393337   41000.00
# 58                                Ethiopia               94101   30000.00
# 134                            Philippines               98394   27000.00
# 116                                Myanmar               53259   26000.00
# 159                           South Africa               52776   25000.00
# 115                             Mozambique               25834   18000.00
# ...
